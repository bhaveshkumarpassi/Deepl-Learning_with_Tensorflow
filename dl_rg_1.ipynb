# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])

# %%
# outlier values khatra 1

# %%
sns.countplot(df['bedrooms'])

# %%
# outlier values khatra 2

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price',y='sqft_living',data=df)

# %%
# really high correlation

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='bedrooms',y='price',data=df)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price',y='long',data=df)

# %%
# long -122.2 has an expensive area

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price',y='lat',data=df)

# %%
# lat 45.5 has an expensive area

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='long',y='lat',data=df,hue='price',palette='coolwarm')

# %%
# the bracket at -122.2 long and 47.6 lat has an expensive block

# %%
# cmapping is not to ideal coz of some outliers in price range so let's deal with them

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['long'],df['lat'],c=df['price'],cmap='viridis')
plt.colorbar()
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('house price on basis of geo-coordinates')
plt.show()

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 8092   1924059029  20140617T000000  4668000.0         5       6.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 8638   3835500195  20140618T000000  4489000.0         4       3.00
# 12370  6065300370  20150506T000000  4208000.0         5       6.00
# 4149   6447300265  20141014T000000  4000000.0         4       5.50
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# ...

# %%
len(df)*0.01
# Out:
# 216.13

# %%
bottom_99_perc = df.sort_values('price',ascending=False)[217:]

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='long',y='lat',data=bottom_99_perc,hue='price',edgecolor=None,alpha=0.2,palette='RdYlGn')

# %%
plt.figure(figsize=(15,10))
plt.scatter(bottom_99_perc['long'],bottom_99_perc['lat'],c=bottom_99_perc['price'],cmap='viridis')
plt.colorbar()
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('house price on basis of geo-coordinates')
plt.show()

# %%
# much clear distribution

# %%
sns.boxplot(x='waterfront',y='price',data=df)

# %%
# houses on waterfront are likely to be more expensive kinda make sense

# %%
df = df.drop('id',axis=1)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
# 5       2014-05-12
# 6       2014-06-27
# 7       2015-01-15
# 8       2015-04-15
# 9       2015-03-12
# 10      2015-04-03
# 11      2014-05-27
# 12      2014-05-28
# 13      2014-10-07
# 14      2015-03-12
# 15      2015-01-24
# 16      2014-07-31
# 17      2014-05-29
# 18      2014-12-05
# 19      2015-04-24
# 20      2014-05-14
# 21      2014-08-26
# 22      2014-07-03
# 23      2014-05-16
# 24      2014-11-20
# 25      2014-11-03
# 26      2014-06-26
# 27      2014-12-01
# 28      2014-06-24
# 29      2015-03-02
#            ...
# 21583   2014-06-10
# 21584   2014-12-02
# 21585   2014-08-28
# 21586   2014-10-15
# 21587   2015-03-05
# 21588   2014-11-13
# 21589   2014-09-10
# 21590   2014-05-14
# 21591   2014-10-02
# 21592   2015-04-16
# 21593   2015-03-17
# 21594   2014-10-17
# 21595   2014-10-31
# 21596   2014-08-13
# 21597   2015-04-21
# 21598   2014-10-13
# ...

# %%
df['date'].values
# Out:
# array(['2014-10-13T00:00:00.000000000', '2014-12-09T00:00:00.000000000',
#        '2015-02-25T00:00:00.000000000', ...,
#        '2014-06-23T00:00:00.000000000', '2015-01-16T00:00:00.000000000',
#        '2014-10-15T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['year'] = df['date'].apply(lambda date : date.year)
df['month'] = df['date'].apply(lambda date : date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month',y='price',data=df)

# %%
df.groupby('month').mean()['price']
# Out:
# month
# 1     525870.889571
# 2     507851.371200
# 3     543977.187200
# 4     561837.774989
# 5     550768.785833
# 6     558002.199541
# 7     544788.764360
# 8     536445.276804
# 9     529253.821871
# 10    539026.971778
# 11    521961.009213
# 12    524461.866757
# Name: price, dtype: float64

# %%
df.groupby('month').mean()['price'].plot()

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# year             0.003576
# month           -0.010081
# zipcode         -0.053203
# Name: price, dtype: float64

# %%
df = df.drop('date',axis=1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
#df['zipcode'].value_counts()

# %%
# zipcode is numeric so our model could think it as let's say code 98>90 which is not true if we either have had a domain 
# knowledge as which zipcodes could be expensive and which not or could convert them to categories but as coategory length 
# is huge which is 70 so i would like to drop it

# %%
df = df.drop('zipcode',axis=1)

# %%
#df['yr_renovated'].value_counts()

# %%
#df['sqft_basement'].value_counts()

# %%
X = df.drop('price',axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15129, 19)

# %%
model = Sequential()

# roughly we can get an idea of neurons in a layer and no. of layers from the shape of train set another way is early stopping
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),
         batch_size=128,epochs=600) 
# validation data added is nothing like leaking data it will not contibute towards parameter updates by an optimizer but
# it's just added so we can keep a check of how our model is performing on train set and test set as well
# Out:
# Train on 14977 samples, validate on 6419 samples
# Epoch 1/600
# 14977/14977 [==============================] - 1s 48us/sample - loss: 346785070704.1635 - val_loss: 354912117094.6154
# Epoch 2/600
# 14977/14977 [==============================] - 0s 15us/sample - loss: 330420127023.5012 - val_loss: 286354666849.6700
# Epoch 3/600
# 14977/14977 [==============================] - 0s 14us/sample - loss: 135177365216.1560 - val_loss: 56647630094.0782
# Epoch 4/600
# 14977/14977 [==============================] - 0s 16us/sample - loss: 55136182575.5695 - val_loss: 54897982505.3173
# Epoch 5/600
# 14977/14977 [==============================] - 0s 15us/sample - loss: 53459799284.2914 - val_loss: 53071137900.9565
# Epoch 6/600
# 14977/14977 [==============================] - 0s 15us/sample - loss: 51805506860.0825 - val_loss: 51320940036.3870
# Epoch 7/600
# 14977/14977 [==============================] - 0s 18us/sample - loss: 50043704336.0673 - val_loss: 49572911820.2736
# Epoch 8/600
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()

# %%
from sklearn import metrics

# %%
predictions = model.predict(X_test)

# %%
np.sqrt(metrics.mean_squared_error(y_test,predictions))
# Out:
# 114393.78381547867

# %%
metrics.mean_absolute_error(y_test,predictions)
# Out:
# 73854.80008568313

# %%
metrics.explained_variance_score(y_test,predictions)
# Out:
# 0.8415181787543287

# %%
metrics.explained_variance_score(y_train,model.predict(X_train))
# Out:
# 0.8459896767675565

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r--')

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %%
scaled_single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(scaled_single_house)
# Out:
# array([[1646739.1]], dtype=float32)

# %%
# our model couldn't predict well  on some outliers this could also be a reason for not to well accuracy of our model
